# %%
## Plotting graphs with matplotlib

# %% [markdown]
# Exercise: Population Berlin
#
# Use the dictionary under here to plot a graph showing the growth of Berlin down the centuries(x years in centuries, y in hundred thousands)

# %%
from matplotlib import pyplot as py
Berlin_dict= {1250:1200,1307:7000,1400:8500,1576:12000,1600:9000,1631:8100,1648:6000,1685:17500,1709:57000,1750:113289,1775:136137,1800:172132,1825:219968,1840:322626,1852:426600,1864:632700,1875:969050,1919:1902509,1933:4242501,1945:2807405,1970:3208719,2000:3382169,2020:3664088}

# %%
from matplotlib import pyplot as plt

Berlin_years = Berlin_dict.keys()
print(Berlin_years)
Berlin_popul = Berlin_dict.values()
print(Berlin_popul)
plt.title("Berlin population growth")
plt.xlabel("Years")
plt.xlabel("Population as 100.000")
plt.plot (Berlin_years, Berlin_popul, ".:r")
plt.grid()
plt.show()
# Out:
# dict_keys([1250, 1307, 1400, 1576, 1600, 1631, 1648, 1685, 1709, 1750, 1775, 1800, 1825, 1840, 1852, 1864, 1875, 1919, 1933, 1945, 1970, 2000, 2020])
# dict_values([1200, 7000, 8500, 12000, 9000, 8100, 6000, 17500, 57000, 113289, 136137, 172132, 219968, 322626, 426600, 632700, 969050, 1902509, 4242501, 2807405, 3208719, 3382169, 3664088])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [29], line 8
#       6 print(Berlin_popul)
#       7 plt.title("Berlin population growth")
# ----> 8 plt.xlabel("Years")
#       9 plt.ylabel("Population as 100.000")
#      10 plt.plot (Berlin_years, Berlin_popul, ".:r")
#
# TypeError: 'str' object is not callable
